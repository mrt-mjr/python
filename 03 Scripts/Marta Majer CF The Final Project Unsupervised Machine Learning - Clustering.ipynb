# %% [markdown]
# ### This script contains the following:
#
# #### 1. Importing libraries and data cleaning
# #### 2. The elbow technique
# #### 3. k-means clustering

# %% [markdown]
# ### 1. Importing libraries and data cleaning

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.cluster import KMeans # Here is where you import the k-means algorithm from scikit-learn.
import pylab as pl # PyLab is a convenience module that bulk imports matplotlib.
from sklearn.preprocessing import StandardScaler # standardizing

# %%
# This option ensures the graphs you create are displayed in your notebook without the need to "call" them specifically.

# %matplotlib inline

# %%
# seting up folder path

path = '/Users/martamajer/Desktop/Desktop - Marta’s MacBook Air - 1/10-2024 Mental Health Database/'

# importing datasets

mental_illness_prevalence_burden_daly = pd.read_csv(os.path.join(path, '02 Data','Prepared Data', 'mental_illness_prevalence_burden_daly.csv'), index_col = False)
anxiety_disorders_treatment_gap = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', '05_anxiety_disorders_treatment_gap.csv'), index_col = False)
depressive_symptoms_across_us_population = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', '06_depressive_symptoms_across_us_population.csv'), index_col = False)
adult_population_covered_in_primary_data_on_the_prevalence_of_mental_illnesses = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', '04_adult_population_covered_in_primary_data_on_the_prevalence_of_mental_illnesses.csv'), index_col = False)

# %%
mental_illness_prevalence_burden_daly.shape
# Out:
# (6150, 14)

# %%
# dropping the column that is unneccesary 

mental_illness_prevalence_burden_daly.drop('Unnamed: 0', axis=1, inplace=True)

# %%
mental_illness_prevalence_burden_daly.head()
# Out:
#   Country(Entity)  Year Code  Rate: Schizophrenia  Rate: Depressive disorders  \
# 0     Afghanistan  1990  AFG             0.223206                    4.996118
# 1     Afghanistan  1991  AFG             0.222454                    4.989290
# 2     Afghanistan  1992  AFG             0.221751                    4.981346
# 3     Afghanistan  1993  AFG             0.220987                    4.976958
# 4     Afghanistan  1994  AFG             0.220183                    4.977782
#
#    Rate: Anxiety disorders  Rate: Bipolar disorders  Rate: Eating disorders  \
# 0                 4.713314                 0.703023                0.127700
# 1                 4.702100                 0.702069                0.123256
# 2                 4.683743                 0.700792                0.118844
# 3                 4.673549                 0.700087                0.115089
# 4                 4.670810                 0.699898                0.111815
#
#    DALYs: Schizophrenia  DALYs: Depressive disorders  \
# 0             138.24825                    895.22565
# 1             137.76122                    893.88434
# 2             137.08030                    892.34973
# 3             136.48602                    891.51587
# 4             136.18323                    891.39160
#
#    DALYs: Anxiety disorders  DALYs: Bipolar disorder  DALYs: Eating disorders
# 0                 440.33000                147.64412                26.471115
# 1                 439.47202                147.56696                25.548681
# 2                 437.60718                147.13086                24.637949
# 3                 436.69104                146.78812                23.863169
# 4                 436.76800                146.58481                23.189074

# %%
df = mental_illness_prevalence_burden_daly

# %%
df.head()
# Out:
#   Country(Entity)  Year Code  Rate: Schizophrenia  Rate: Depressive disorders  \
# 0     Afghanistan  1990  AFG             0.223206                    4.996118
# 1     Afghanistan  1991  AFG             0.222454                    4.989290
# 2     Afghanistan  1992  AFG             0.221751                    4.981346
# 3     Afghanistan  1993  AFG             0.220987                    4.976958
# 4     Afghanistan  1994  AFG             0.220183                    4.977782
#
#    Rate: Anxiety disorders  Rate: Bipolar disorders  Rate: Eating disorders  \
# 0                 4.713314                 0.703023                0.127700
# 1                 4.702100                 0.702069                0.123256
# 2                 4.683743                 0.700792                0.118844
# 3                 4.673549                 0.700087                0.115089
# 4                 4.670810                 0.699898                0.111815
#
#    DALYs: Schizophrenia  DALYs: Depressive disorders  \
# 0             138.24825                    895.22565
# 1             137.76122                    893.88434
# 2             137.08030                    892.34973
# 3             136.48602                    891.51587
# 4             136.18323                    891.39160
#
#    DALYs: Anxiety disorders  DALYs: Bipolar disorder  DALYs: Eating disorders
# 0                 440.33000                147.64412                26.471115
# 1                 439.47202                147.56696                25.548681
# 2                 437.60718                147.13086                24.637949
# 3                 436.69104                146.78812                23.863169
# 4                 436.76800                146.58481                23.189074

# %%
df.describe()
# Out:
#               Year  Rate: Schizophrenia  Rate: Depressive disorders  \
# count  6150.000000          6150.000000                 6150.000000
# mean   2004.500000             0.266031                    3.766168
# std       8.656145             0.039258                    0.939617
# min    1990.000000             0.188416                    1.522333
# 25%    1997.000000             0.241982                    3.063132
# 50%    2004.500000             0.272983                    3.642872
# 75%    2012.000000             0.285912                    4.369088
# max    2019.000000             0.462045                    7.645899
#
#        Rate: Anxiety disorders  Rate: Bipolar disorders  \
# count              6150.000000              6150.000000
# mean                  4.098702                 0.638366
# std                   1.060642                 0.235506
# min                   1.879996                 0.181667
# 25%                   3.425237                 0.521153
# 50%                   3.939547                 0.579017
# 75%                   4.539975                 0.853304
# max                   8.624634                 1.506730
#
#        Rate: Eating disorders  DALYs: Schizophrenia  \
# count             6150.000000           6150.000000
# mean                 0.194945            170.168725
# std                  0.139051             25.574189
# min                  0.044780            119.913380
# 25%                  0.095748            154.312173
# 50%                  0.144325            174.697920
# 75%                  0.242860            183.565115
# max                  1.031688            291.100100
#
#        DALYs: Depressive disorders  DALYs: Anxiety disorders  \
# count                  6150.000000               6150.000000
# mean                    650.147720                391.391882
# std                     189.881727                101.513141
# min                     243.097840                180.049640
# 25%                     500.949597                326.350750
# 50%                     630.373350                375.719120
# 75%                     764.889150                433.911575
# max                    1427.423600                814.302300
#
#        DALYs: Bipolar disorder  DALYs: Eating disorders
# count              6150.000000              6150.000000
# mean                137.602358                41.622553
# std                  50.977136                29.615846
# min                  39.438133                 9.671199
# 25%                 112.243175                20.541226
# 50%                 123.508730                30.762172
# 75%                 184.623580                51.641518
# max                 325.152800               218.704390

# %%
# Filter for the year 2019
df = df[df['Year'] == 2019]

# List of columns to keep
columns_to_keep = [
    "Rate: Schizophrenia", "Rate: Depressive disorders", "Rate: Anxiety disorders",
    "Rate: Bipolar disorders", "Rate: Eating disorders", 
    "DALYs: Schizophrenia", "DALYs: Depressive disorders", 
    "DALYs: Anxiety disorders", "DALYs: Bipolar disorder", "DALYs: Eating disorders"
]

# Select only these columns in the filtered DataFrame
df = df[columns_to_keep]

# %%
df
# Out:
#       Rate: Schizophrenia  Rate: Depressive disorders  \
# 29               0.217777                    4.945168
# 59               0.287501                    2.460203
# 89               0.249135                    4.129681
# 119              0.303400                    2.659042
# 149              0.286518                    3.607207
# ...                   ...                         ...
# 6029             0.323551                    2.473061
# 6059             0.287409                    3.440053
# 6089             0.225680                    4.895368
# 6119             0.212869                    4.219490
# 6149             0.202482                    3.395476
#
#       Rate: Anxiety disorders  Rate: Bipolar disorders  \
# 29                   4.851035                 0.699645
# 59                   3.837537                 0.542009
# 89                   4.771976                 0.756275
# 119                  4.044245                 0.279732
# 149                  5.453410                 0.934813
# ...                       ...                      ...
# 6029                 2.287339                 0.336103
# 6059                 3.779522                 0.489817
# 6089                 4.783716                 0.725980
# 6119                 3.969207                 0.574454
# 6149                 3.137017                 0.538580
#
#       Rate: Eating disorders  DALYs: Schizophrenia  \
# 29                  0.117414             135.63637
# 59                  0.136648             185.53891
# 89                  0.210603             160.01306
# 119                 0.128156             192.81041
# 149                 0.520892             183.04898
# ...                      ...                   ...
# 6029                0.094745             210.68578
# 6059                0.173952             184.14943
# 6089                0.123512             143.32640
# 6119                0.114669             134.65456
# 6149                0.098295             128.21603
#
#       DALYs: Depressive disorders  DALYs: Anxiety disorders  \
# 29                      890.18880                 457.24570
# 59                      386.41925                 368.11500
# 89                      736.51490                 458.80023
# 119                     393.94205                 384.18695
# 149                     626.02860                 522.78680
# ...                           ...                       ...
# 6029                    360.23220                 220.24388
# 6059                    577.74695                 360.12097
# 6089                    890.98820                 455.44073
# 6119                    708.93510                 375.89227
# 6149                    544.53160                 298.20325
#
#       DALYs: Bipolar disorder  DALYs: Eating disorders
# 29                 148.224640                24.711750
# 59                 117.631195                29.221224
# 89                 163.719420                44.839720
# 119                 59.720222                27.355640
# 149                201.294050               111.030820
# ...                       ...                      ...
# 6029                73.046140                20.586077
# 6059               105.430250                37.189297
# 6089               155.442700                26.062387
# 6119               122.788340                24.392563
# 6149               115.381450                21.011127
#
# [205 rows x 10 columns]

# %% [markdown]
# ### standardizing data

# %%
#scaler = StandardScaler()
# df = scaler.fit_transform(df)

# %%
# df.head()

# %% [markdown]
# ### 2. The elbow technique

# %%
num_cl = range(1, 10) # Defines the range of potential clusters in the data.
kmeans = [KMeans(n_clusters=i) for i in num_cl] # Defines k-means clusters in the range assigned above.

# %%
score = [kmeans[i].fit(df).score(df) for i in range(len(kmeans))] # Creates a score that represents 
# a rate of variation for the given cluster option.

score
# Out:
# [-9680632.888939053,
#  -5093325.450641107,
#  -3672978.1913958807,
#  -2783068.899257576,
#  -2327615.897694994,
#  -1953589.114061206,
#  -1799199.1937803775,
#  -1580955.8530780813,
#  -1416129.6440665107]

# %%
# Plot the elbow curve using PyLab.

pl.plot(num_cl,score)
pl.xlabel('Number of Clusters')
pl.ylabel('Score')
pl.title('Elbow Curve')
pl.show()

# %% [markdown]
# #####  In this example, there's a large jump from two to three on the x-axis, but after that, the curve straightens out. This means that the optimal count for your clusters is three.

# %% [markdown]
# ### 3. k-means clustering

# %%
# Create the k-means object.

kmeans = KMeans(n_clusters = 3)

# %%
# Fit the k-means object to the data.

kmeans.fit(df)
# Out:
# KMeans(n_clusters=3)

# %%
df['clusters'] = kmeans.fit_predict(df)

# %%
df.head()
# Out:
#      Rate: Schizophrenia  Rate: Depressive disorders  Rate: Anxiety disorders  \
# 29              0.217777                    4.945168                 4.851035
# 59              0.287501                    2.460203                 3.837537
# 89              0.249135                    4.129681                 4.771976
# 119             0.303400                    2.659042                 4.044245
# 149             0.286518                    3.607207                 5.453410
#
#      Rate: Bipolar disorders  Rate: Eating disorders  DALYs: Schizophrenia  \
# 29                  0.699645                0.117414             135.63637
# 59                  0.542009                0.136648             185.53891
# 89                  0.756275                0.210603             160.01306
# 119                 0.279732                0.128156             192.81041
# 149                 0.934813                0.520892             183.04898
#
#      DALYs: Depressive disorders  DALYs: Anxiety disorders  \
# 29                     890.18880                 457.24570
# 59                     386.41925                 368.11500
# 89                     736.51490                 458.80023
# 119                    393.94205                 384.18695
# 149                    626.02860                 522.78680
#
#      DALYs: Bipolar disorder  DALYs: Eating disorders  clusters
# 29                148.224640                24.711750         0
# 59                117.631195                29.221224         1
# 89                163.719420                44.839720         2
# 119                59.720222                27.355640         1
# 149               201.294050               111.030820         2

# %%
df['clusters'].value_counts()
# Out:
# clusters
# 2    80
# 1    71
# 0    54
# Name: count, dtype: int64

# %% [markdown]
# #### chosing to compare bipolar and depression as those are usually misdiagnosed.

# %%
# Plot the clusters for the "Rate: Depressive disorders" and "Rate: Bipolar disorders" variables.

plt.figure(figsize=(8,5))
ax = sns.scatterplot(x=df['Rate: Depressive disorders'], y=df['Rate: Bipolar disorders'], hue=kmeans.labels_, s=100) 
# Here, you're subsetting `X` for the x and y arguments to avoid using their labels. 
# `hue` takes the value of the attribute `kmeans.labels_`, which is the result of running the k-means algorithm.
# `s` represents the size of the points you want to see in the plot.

ax.grid(False) # This removes the grid from the background.
plt.xlabel('Rate: Depressive disorders') # Label x-axis.
plt.ylabel('Rate: Bipolar disorders') # Label y-axis.
plt.show()

# %% [markdown]
# #### you can do more graphs for exploration

# %%
df.loc[df['clusters'] == 2, 'cluster'] = 'dark purple'
df.loc[df['clusters'] == 1, 'cluster'] = 'purple'
df.loc[df['clusters'] == 0, 'cluster'] = 'pink'

# %%
# Group by 'cluster' and aggregate the specified columns
result = df.groupby('cluster').agg({
    'Rate: Schizophrenia': ['mean', 'median'],
    'Rate: Depressive disorders': ['mean', 'median'],
    'Rate: Anxiety disorders': ['mean', 'median'],
    'Rate: Bipolar disorders': ['mean', 'median'],
    'Rate: Eating disorders': ['mean', 'median'],
    'DALYs: Schizophrenia': ['mean', 'median'],
    'DALYs: Depressive disorders': ['mean', 'median'],
    'DALYs: Anxiety disorders': ['mean', 'median'],
    'DALYs: Bipolar disorder': ['mean', 'median'],
    'DALYs: Eating disorders': ['mean', 'median']
})

# %%
result
# Out:
#             Rate: Schizophrenia           Rate: Depressive disorders  \
#                            mean    median                       mean
# cluster
# dark purple            0.279515  0.277217                   3.668329
# pink                   0.229155  0.217411                   4.874963
# purple                 0.283750  0.287501                   2.866516
#
#                       Rate: Anxiety disorders            \
#                median                    mean    median
# cluster
# dark purple  3.700012                4.797549  4.480276
# pink         4.730175                3.990678  3.734509
# purple       2.878852                3.554790  3.612120
#
#             Rate: Bipolar disorders           Rate: Eating disorders  \
#                                mean    median                   mean
# cluster
# dark purple                0.819319  0.888704               0.310248
# pink                       0.621412  0.578984               0.149588
# purple                     0.449048  0.500296               0.152433
#
#                       DALYs: Schizophrenia             \
#                median                 mean     median
# cluster
# dark purple  0.268011           178.673989  177.43747
# pink         0.113660           145.835852  138.70085
# purple       0.128156           182.448735  185.06987
#
#             DALYs: Depressive disorders            DALYs: Anxiety disorders  \
#                                    mean     median                     mean
# cluster
# dark purple                  642.887578  647.65161               458.828126
# pink                         867.443429  841.13917               380.252992
# purple                       459.327996  456.63318               339.974296
#
#                         DALYs: Bipolar disorder              \
#                  median                    mean      median
# cluster
# dark purple  427.655235              176.834985  191.492105
# pink         354.963805              133.532186  124.466141
# purple       348.510560               97.107047  109.010520
#
#             DALYs: Eating disorders
#                                mean     median
# cluster
# dark purple               66.164102  57.131988
# pink                      31.826942  24.312658
# purple                    32.785194  27.402382

# %%
# Get the country information back
df_with_countries = mental_illness_prevalence_burden_daly[mental_illness_prevalence_burden_daly['Year'] == 2019]
df_with_clusters = df.copy()
df_with_clusters['Country'] = df_with_countries['Country(Entity)'].values

# View countries in each cluster
print("Countries in each cluster:")
for cluster_name in ['dark purple', 'purple', 'pink']:
    countries = df_with_clusters[df_with_clusters['cluster'] == cluster_name]['Country'].tolist()
    print(f"\n{cluster_name.upper()} cluster ({len(countries)} countries):")
    print(', '.join(sorted(countries)))

# For a more organized tabular view:
print("\nTabular view of countries and their clusters:")
country_clusters = df_with_clusters[['Country', 'cluster']].sort_values(['cluster', 'Country'])
print(country_clusters.to_string())
# Out:
# Countries in each cluster:
#
# DARK PURPLE cluster (80 countries):
# Algeria, Andorra, Antigua and Barbuda, Australia, Austria, Bahamas, Barbados, Belarus, Belgium, Belize, Bermuda, Bhutan, Bolivia, Brazil, Canada, Chile, Costa Rica, Cote d'Ivoire, Cuba, Cyprus, Denmark, Dominica, Dominican Republic, Ecuador, Egypt, El Salvador, Estonia, Finland, France, Germany, Grenada, Guatemala, Haiti, Honduras, Iceland, Iraq, Ireland, Israel, Italy, Jamaica, Jordan, Kuwait, Latvia, Lithuania, Luxembourg, Malawi, Malaysia, Malta, Mauritius, Mexico, Monaco, Netherlands, New Zealand, Nicaragua, Nigeria, Norway, Oman, Pakistan, Paraguay, Portugal, Qatar, Saint Kitts and Nevis, Saint Lucia, Saint Vincent and the Grenadines, San Marino, Saudi Arabia, Senegal, Sweden, Switzerland, Syria, Trinidad and Tobago, Turkey, Ukraine, United Arab Emirates, United Kingdom, United States, United States Virgin Islands, Uruguay, Venezuela, Zambia
#
# PURPLE cluster (71 countries):
# Albania, American Samoa, Argentina, Armenia, Azerbaijan, Bosnia and Herzegovina, Brunei, Bulgaria, Cambodia, China, Colombia, Cook Islands, Croatia, Czechia, East Timor, Fiji, Georgia, Guam, Hungary, India, Indonesia, Japan, Kazakhstan, Kiribati, Kyrgyzstan, Laos, Maldives, Mali, Marshall Islands, Mauritania, Micronesia (country), Moldova, Montenegro, Myanmar, Namibia, Nauru, Niue, North Korea, North Macedonia, Northern Mariana Islands, Palau, Panama, Papua New Guinea, Peru, Philippines, Poland, Puerto Rico, Romania, Russia, Samoa, Sao Tome and Principe, Serbia, Seychelles, Singapore, Slovakia, Slovenia, Solomon Islands, South Korea, Sri Lanka, Taiwan, Tajikistan, Thailand, Tokelau, Tonga, Turkmenistan, Tuvalu, Uzbekistan, Vanuatu, Vietnam, World, Zimbabwe
#
# PINK cluster (54 countries):
# Afghanistan, Angola, Bahrain, Bangladesh, Benin, Botswana, Burkina Faso, Burundi, Cameroon, Cape Verde, Central African Republic, Chad, Comoros, Congo, Democratic Republic of Congo, Djibouti, Equatorial Guinea, Eritrea, Eswatini, Ethiopia, Gabon, Gambia, Ghana, Greece, Greenland, Guinea, Guinea-Bissau, Guyana, Iran, Kenya, Lebanon, Lesotho, Liberia, Libya, Madagascar, Mongolia, Morocco, Mozambique, Nepal, Niger, Palestine, Rwanda, Sierra Leone, Somalia, South Africa, South Sudan, Spain, Sudan, Suriname, Tanzania, Togo, Tunisia, Uganda, Yemen
#
# Tabular view of countries and their clusters:
#                                Country      cluster
# 89                             Algeria  dark purple
# 149                            Andorra  dark purple
# 209                Antigua and Barbuda  dark purple
# 299                          Australia  dark purple
# 329                            Austria  dark purple
# 389                            Bahamas  dark purple
# 479                           Barbados  dark purple
# 509                            Belarus  dark purple
# 539                            Belgium  dark purple
# 569                             Belize  dark purple
# 629                            Bermuda  dark purple
# 659                             Bhutan  dark purple
# 689                            Bolivia  dark purple
# 779                             Brazil  dark purple
# 989                             Canada  dark purple
# 1109                             Chile  dark purple
# 1289                        Costa Rica  dark purple
# 1319                     Cote d'Ivoire  dark purple
# 1379                              Cuba  dark purple
# 1409                            Cyprus  dark purple
# 1499                           Denmark  dark purple
# 1559                          Dominica  dark purple
# 1589                Dominican Republic  dark purple
# 1649                           Ecuador  dark purple
# 1679                             Egypt  dark purple
# 1709                       El Salvador  dark purple
# 1799                           Estonia  dark purple
# 1919                           Finland  dark purple
# 1949                            France  dark purple
# 2069                           Germany  dark purple
# 2189                           Grenada  dark purple
# 2249                         Guatemala  dark purple
# 2369                             Haiti  dark purple
# 2399                          Honduras  dark purple
# 2459                           Iceland  dark purple
# 2579                              Iraq  dark purple
# 2609                           Ireland  dark purple
# 2639                            Israel  dark purple
# 2669                             Italy  dark purple
# 2699                           Jamaica  dark purple
# 2759                            Jordan  dark purple
# 2879                            Kuwait  dark purple
# 2969                            Latvia  dark purple
# 3119                         Lithuania  dark purple
# 3149                        Luxembourg  dark purple
# 3209                            Malawi  dark purple
# 3239                          Malaysia  dark purple
# 3329                             Malta  dark purple
# 3419                         Mauritius  dark purple
# 3449                            Mexico  dark purple
# 3539                            Monaco  dark purple
# 3809                       Netherlands  dark purple
# 3839                       New Zealand  dark purple
# 3869                         Nicaragua  dark purple
# 3929                           Nigeria  dark purple
# 4079                            Norway  dark purple
# 4109                              Oman  dark purple
# 4139                          Pakistan  dark purple
# 4289                          Paraguay  dark purple
# 4409                          Portugal  dark purple
# 4469                             Qatar  dark purple
# 4589             Saint Kitts and Nevis  dark purple
# 4619                       Saint Lucia  dark purple
# 4649  Saint Vincent and the Grenadines  dark purple
# 4709                        San Marino  dark purple
# 4769                      Saudi Arabia  dark purple
# 4799                           Senegal  dark purple
# 5279                            Sweden  dark purple
# 5309                       Switzerland  dark purple
# 5339                             Syria  dark purple
# 5579               Trinidad and Tobago  dark purple
# 5639                            Turkey  dark purple
# 5759                           Ukraine  dark purple
# 5789              United Arab Emirates  dark purple
# 5819                    United Kingdom  dark purple
# 5849                     United States  dark purple
# 5879      United States Virgin Islands  dark purple
# 5909                           Uruguay  dark purple
# 5999                         Venezuela  dark purple
# 6119                            Zambia  dark purple
# 29                         Afghanistan         pink
# 179                             Angola         pink
# 419                            Bahrain         pink
# 449                         Bangladesh         pink
# 599                              Benin         pink
# 749                           Botswana         pink
# 869                       Burkina Faso         pink
# 899                            Burundi         pink
# 959                           Cameroon         pink
# 1019                        Cape Verde         pink
# 1049          Central African Republic         pink
# 1079                              Chad         pink
# 1199                           Comoros         pink
# 1229                             Congo         pink
# 1469      Democratic Republic of Congo         pink
# 1529                          Djibouti         pink
# 1739                 Equatorial Guinea         pink
# 1769                           Eritrea         pink
# 1829                          Eswatini         pink
# 1859                          Ethiopia         pink
# 1979                             Gabon         pink
# 2009                            Gambia         pink
# 2099                             Ghana         pink
# 2129                            Greece         pink
# 2159                         Greenland         pink
# 2279                            Guinea         pink
# 2309                     Guinea-Bissau         pink
# 2339                            Guyana         pink
# 2549                              Iran         pink
# 2819                             Kenya         pink
# 2999                           Lebanon         pink
# 3029                           Lesotho         pink
# 3059                           Liberia         pink
# 3089                             Libya         pink
# 3179                        Madagascar         pink
# 3569                          Mongolia         pink
# 3629                           Morocco         pink
# 3659                        Mozambique         pink
# 3779                             Nepal         pink
# 3899                             Niger         pink
# 4199                         Palestine         pink
# 4559                            Rwanda         pink
# 4889                      Sierra Leone         pink
# 5039                           Somalia         pink
# 5069                      South Africa         pink
# 5129                       South Sudan         pink
# 5159                             Spain         pink
# 5219                             Sudan         pink
# 5249                          Suriname         pink
# 5429                          Tanzania         pink
# 5489                              Togo         pink
# 5609                           Tunisia         pink
# 5729                            Uganda         pink
# 6089                             Yemen         pink
# 59                             Albania       purple
# 119                     American Samoa       purple
# 239                          Argentina       purple
# 269                            Armenia       purple
# 359                         Azerbaijan       purple
# 719             Bosnia and Herzegovina       purple
# 809                             Brunei       purple
# 839                           Bulgaria       purple
# 929                           Cambodia       purple
# 1139                             China       purple
# 1169                          Colombia       purple
# 1259                      Cook Islands       purple
# 1349                           Croatia       purple
# 1439                           Czechia       purple
# 1619                        East Timor       purple
# 1889                              Fiji       purple
# 2039                           Georgia       purple
# 2219                              Guam       purple
# 2429                           Hungary       purple
# 2489                             India       purple
# 2519                         Indonesia       purple
# 2729                             Japan       purple
# 2789                        Kazakhstan       purple
# 2849                          Kiribati       purple
# 2909                        Kyrgyzstan       purple
# 2939                              Laos       purple
# 3269                          Maldives       purple
# 3299                              Mali       purple
# 3359                  Marshall Islands       purple
# 3389                        Mauritania       purple
# 3479              Micronesia (country)       purple
# 3509                           Moldova       purple
# 3599                        Montenegro       purple
# 3689                           Myanmar       purple
# 3719                           Namibia       purple
# 3749                             Nauru       purple
# 3959                              Niue       purple
# 3989                       North Korea       purple
# 4019                   North Macedonia       purple
# 4049          Northern Mariana Islands       purple
# 4169                             Palau       purple
# 4229                            Panama       purple
# 4259                  Papua New Guinea       purple
# 4319                              Peru       purple
# 4349                       Philippines       purple
# 4379                            Poland       purple
# 4439                       Puerto Rico       purple
# 4499                           Romania       purple
# 4529                            Russia       purple
# 4679                             Samoa       purple
# 4739             Sao Tome and Principe       purple
# 4829                            Serbia       purple
# 4859                        Seychelles       purple
# 4919                         Singapore       purple
# 4949                          Slovakia       purple
# 4979                          Slovenia       purple
# 5009                   Solomon Islands       purple
# 5099                       South Korea       purple
# 5189                         Sri Lanka       purple
# 5369                            Taiwan       purple
# 5399                        Tajikistan       purple
# 5459                          Thailand       purple
# 5519                           Tokelau       purple
# 5549                             Tonga       purple
# 5669                      Turkmenistan       purple
# 5699                            Tuvalu       purple
# 5939                        Uzbekistan       purple
# 5969                           Vanuatu       purple
# 6029                           Vietnam       purple
# 6059                             World       purple
# 6149                          Zimbabwe       purple

# %% [markdown]
# ## INSIGHTS:

# %% [markdown]
# ### TL;DR:
#
# - There's significant regional variation in mental health burden
# - Conditions tend to cluster together - regions with high rates of one condition often have high rates of others
# - The disease burden (DALYs) generally aligns with prevalence rates
# - The dark purple cluster shows particular vulnerability to depression
# - The pink cluster shows the highest overall burden across multiple conditions
#
# **1. DARK PURPLE cluster (53 countries):**
#
# Most African countries (e.g., Angola, Botswana, Burkina Faso, Ethiopia)
# Some Middle Eastern countries (Afghanistan, Bahrain, Iran, Yemen)
# Few Southern European countries (Greece, Spain)
# Some Asian countries (Bangladesh, Mongolia, Nepal)
# Few South American countries (Guyana, Suriname)
#
# Highest rates of depressive disorders (mean: 4.88)
# Lowest rates of schizophrenia (mean: 0.23)
# Mid-range anxiety rates (mean: 3.97)
# Moderate bipolar disorder rates (mean: 0.62)
# Lowest eating disorder rates (mean: 0.15)
# Highest DALYs (Disability-Adjusted Life Years) for depressive disorders (mean: 868.88)
# Mid-range DALYs for anxiety disorders (mean: 377.81)
#
# **2. PURPLE cluster (72 countries):**
#
# Many Asian countries (China, Japan, Indonesia, Vietnam, Cambodia)
# Most Eastern European countries (Albania, Croatia, Hungary, Poland)
# Pacific Island nations (Fiji, Samoa, Solomon Islands)
# Some South American countries (Argentina, Colombia, Peru)
#
# Highest rates of schizophrenia (mean: 0.28)
# Lowest rates of depressive disorders (mean: 2.87)
# Lowest rates of anxiety disorders (mean: 3.56)
# Lowest rates of bipolar disorders (mean: 0.46)
# Lowest DALYs for depressive disorders (mean: 460.34)
# Lowest DALYs for anxiety disorders (mean: 340.64)
# Lowest DALYs for bipolar disorder (mean: 98.60)
#
# **3. PINK cluster (80 countries):**
#
# Most Western European countries (France, Germany, UK, Netherlands)
# North American countries (USA, Canada, Mexico)
# Most Oceania developed nations (Australia, New Zealand)
# Most Middle Eastern wealthy nations (UAE, Kuwait, Qatar)
# Some South American countries (Brazil, Chile, Uruguay)
#
# Highest rates of anxiety disorders (mean: 4.81)
# Highest rates of bipolar disorders (mean: 0.82)
# Highest rates of eating disorders (mean: 0.31)
# Highest DALYs for anxiety disorders (mean: 460.35)
# Highest DALYs for bipolar disorder (mean: 176.35)
# Highest DALYs for eating disorders (mean: 66.18)
#
# **---> Key patterns:**
#
# **Economic development seems to correlate with cluster membership:**
#
# - Pink cluster contains most developed/high-income nations
# - Dark purple cluster contains many developing nations
# - Purple cluster is mixed but includes many middle-income countries
#
#
# **Geographic patterns:**
#
# - Western Europe is predominantly in the pink cluster
# - Eastern Europe is predominantly in the purple cluster
# - Africa is predominantly in the dark purple cluster
# - Asia is split between purple and dark purple clusters
# - The Americas are split between pink and purple clusters
#
#
# **Cultural/Regional patterns:**
#
# - Most Nordic countries are in the pink cluster
# - Most Pacific islands are in the purple cluster
# - Most Gulf states are in the pink cluster
#
#
# **DARK PURPLE cluster cluster appears to represent regions with particularly high depression burden but relatively lower rates of other mental health conditions.**
#
# **PURPLE cluster represents regions with relatively lower mental health burden across most conditions, except for slightly higher schizophrenia rates.**
#
# **PINK cluster seems to represent regions with more diverse mental health challenges, particularly high anxiety and bipolar disorder rates.**

# %% [markdown]
# #### I was interested in countries with progressive mental health treatments, such as the United States, Canada, Brazil, the Netherlands, Jamaica, Switzerland, Portugal, and Mexico.
#
# All countries, except Jamaica, belong to the pink cluster, which is characterized by:
#
# - Higher rates of anxiety disorders
# - Higher rates of bipolar disorders
# - Higher rates of eating disorders
# - The highest DALYs (disease burden) for anxiety, bipolar, and eating disorders
#
# Jamaica, on the other hand, is part of the purple cluster, characterized by:
#
# - Relatively lower mental health burden across most conditions
# - Higher rates of schizophrenia
# - Lower rates of depressive disorders
# - Lower rates of anxiety disorders
# - Lower overall DALYs
#
# **This suggests a substantial opportunity to offer individuals innovative treatment options. Further analysis will be conducted to examine the timeline and identify which countries have successfully reduced the prevalence of disorders over time.**
